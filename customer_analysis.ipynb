# %% [markdown]
# <a href="https://colab.research.google.com/github/jesronithin/Customer-analysis/blob/main/customer_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("/content/Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.shape
# Out:
# (200, 5)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df.drop("CustomerID",axis=1)

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
sns.countplot(x="Gender",data=df,hue="Gender")
plt.title("Gender")
plt.show()

# %%
plt.bar(df["Gender"],df["Spending Score (1-100)"])
plt.xlabel("Gender")
plt.ylabel("Spending Score (1-100)")
plt.title("Bar graph")
# Out:
# Text(0.5, 1.0, 'Bar graph')

# %%
plt.hist(df["Annual Income (k$)"])
plt.title("Annual income histogram")
plt.xlabel("Annual Income (k$)")
plt.show()

# %%
plt.scatter(x="Annual Income (k$)",y="Spending Score (1-100)",data=df)
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("scatter plot")
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
plt.boxplot(df["Age"])
plt.show()

# %%
sns.boxplot(df["Annual Income (k$)"])
# Out:
# <Axes: >

# %%
plt.boxplot(df["Spending Score (1-100)"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2621ece410>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f2621ecc970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2621ecea10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2621ecc430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2621eceb90>],
#  'means': []}

# %%
sns.heatmap(df.corr(),cmap="Blues",annot=True)
# Out:
# <ipython-input-36-8fa699c4ca74>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap="Blues",annot=True)
# <Axes: >

# %%
sns.scatterplot(x="Annual Income (k$)",y="Spending Score (1-100)",data=df,hue="Gender")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

# %%
sns.pairplot(df)

# %%
plt.plot(df["Annual Income (k$)"],df['Spending Score (1-100)'])
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("line plot")
# Out:
# Text(0.5, 1.0, 'line plot')

# %%
plt.scatter(x="Annual Income (k$)",y="Spending Score (1-100)",data=df)
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("scatter plot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-39f44c744d52> in <cell line: 1>()
# ----> 1 plt.scatter(x="Annual Income (k$)",y="Spending Score (1-100)",data=df)
#       2 plt.xlabel("Annual Income (k$)")
#       3 plt.ylabel("Spending Score (1-100)")
#       4 plt.title("scatter plot")
#
# NameError: name 'plt' is not defined
